# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
from dotenv import load_dotenv
import os

load_dotenv()

db_host = os.getenv('DB_HOST') 
db_user = os.getenv('DB_USER')
db_pass = os.getenv('DB_PASS')
db_port = os.getenv('DB_PORT')

client = MongoClient(f"mongodb://{db_user}:{db_pass}@{db_host}:{db_port}/")
db = client['twitter']
collection = db['tweets']

data = list(collection.find().limit(10))

df = pd.DataFrame(data)
df
# Out:
#                         _id                   id  \
# 0  60f873c1a0d27b737e6dd9ce  1026814183042686976
# 1  60f873c1a0d27b737e6dd9cf  1026814466145628160
# 2  60f873c1a0d27b737e6dd9d0  1026815522997002240
# 3  60f873c1a0d27b737e6dd9d1  1026815774055452672
# 4  60f873c1a0d27b737e6dd9d2  1026816089110601728
# 5  60f873c1a0d27b737e6dd9d3  1026816185126596608
# 6  60f873c1a0d27b737e6dd9d4  1026816558876844032
# 7  60f873c1a0d27b737e6dd9d5  1026816984787443717
# 8  60f873c1a0d27b737e6dd9d6  1026817603191357441
# 9  60f873c1a0d27b737e6dd9d7  1026817611626172417
#
#                              date  \
# 0  Tue Aug 07 12:55:53 +0000 2018
# 1  Tue Aug 07 12:57:00 +0000 2018
# 2  Tue Aug 07 13:01:12 +0000 2018
# 3  Tue Aug 07 13:02:12 +0000 2018
# 4  Tue Aug 07 13:03:27 +0000 2018
# 5  Tue Aug 07 13:03:50 +0000 2018
# 6  Tue Aug 07 13:05:19 +0000 2018
# 7  Tue Aug 07 13:07:01 +0000 2018
# 8  Tue Aug 07 13:09:28 +0000 2018
# 9  Tue Aug 07 13:09:30 +0000 2018
#
#                                                 text             user_id  \
# 0  RT @de_patty: Asuuuuuuu..  @Renzo_Reggiardo me...           544008122
# 1  @JorgeMunozAP @ap_bancada @AccionPopularPe @Ac...  831616598083588098
# 2  @de_patty @Renzo_Reggiardo @luchocastanedap Y ...           132649817
# 3  RT @de_patty: Asuuuuuuu..  @Renzo_Reggiardo me...           170830041
# 4  RT @MikeReategui: #HablaCastañeda https://t.co...            62131246
# 5  @JorgeMunozAP @ap_bancada @AccionPopularPe @Ac...            66786769
# 6  @JorgeMunozAP @ap_bancada @AccionPopularPe @Ac...          1020629868
# 7  @RecuerdosPeru @Renzo_Reggiardo @RenzopeOficia...           442247879
# 8  @_CorazonSalvaj @JorgeMunozAP @ap_bancada @Acc...           881380951
# 9  @JorgeMunozAP @ap_bancada @AccionPopularPe @Ac...  890311782509707265
#
#          user_name  retweeted  \
# 0  @CARLOSPUEMAPE1       True
# 1    @JovenesConFP      False
# 2          @cefp01      False
# 3         @vladynz       True
# 4       @mundoyola       True
# 5        @lulavitz      False
# 6  @_CorazonSalvaj      False
# 7      @liliana2sd      False
# 8     @Clauditaato      False
# 9   @JudithNancy69      False
#
#                                              RT_text   RT_user_id  \
# 0  Asuuuuuuu..  @Renzo_Reggiardo me da mala espin...  302995560.0
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3  Asuuuuuuu..  @Renzo_Reggiardo me da mala espin...  302995560.0
# 4            #HablaCastañeda https://t.co/fRmACwQ06D   41526072.0
# 5                                                NaN          NaN
# 6                                                NaN          NaN
# 7                                                NaN          NaN
# 8                                                NaN          NaN
# 9                                                NaN          NaN
#
#     RT_user_name
# 0      @de_patty
# 1            NaN
# 2            NaN
# 3      @de_patty
# 4  @MikeReategui
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
